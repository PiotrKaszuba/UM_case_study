# %% [markdown]
# Automated Feature Engineering

# %%
import pandas as pd
import numpy as np
import framequery as fq
import hashlib
import featuretools as ft
from featuretools import Feature 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("train1.csv")
df = df.head(250000)

# %%
df.isnull().sum()
# Brak brakujących wartośći
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       0
# dtype: int64

# %%
df.groupby('matchType').head()
# Out:
#                     Id         groupId         matchId  assists  boosts  \
# 0       75c10f333dfdb2  312d33be84f802  f98cefba51a79c        0       0
# 1       3c9cd47c845b8f  4cfa90a5da9216  cf68f99a6d40fe        0       0
# 2       537fae74d33487  a33d482531298a  faed6a22ecb949        0       0
# 3       8fbc99f2b72da6  157ec1680cae7c  49318240e11fe2        0       0
# 4       15941736eba92d  6bf0b088393514  9fc250a4f0d6d7        0       3
# 5       90f838f5838e43  0310194f0beb21  63cb73d87789bc        0       7
# 6       cb57e6e5560d39  ae3394dc211a18  f9f5a94af344ec        0       0
# 7       e6b8beaf8b4d66  cf567a60174e1e  4c87489c3fb46a        0       1
# 8       e7b238e276b50d  307232d29befa6  6d9eca79d9e756        2       2
# 9       67c0dad5ab4267  2e899451072441  3594728c5ff83b        0       0
# 10      ec281838accc0f  4af944c9ac75f8  f0d96aa97a5f45        0       0
# 11      1c6aa5cb38ce4d  48b2bf0f9e7ffb  0fc812d146d7b5        0       0
# 13      11be6b7dda2275  0f730ce2c76309  05fb9b535f070b        0       0
# 14      d295c690787883  5c5ec84ce788ee  9696c124f451b7        0       0
# 15      3cf62f431fed97  7911a139f3e24f  0989ec5dbcfa72        0       3
# 16      e1c0aa447aae81  b065bd1b640576  daeb24e0880910        0       0
# 18      7fefa16890fd93  142e6bb4e15512  6dfe2c2368a6d8        0       0
# 20      736c337202f03f  384bf100bc636b  c512cd35920ca4        0       0
# 21      8acff4d0cdedc1  485ebea08d03b8  bcca2aae0556bb        0       0
# 22      ab23656bfe9c8c  6de906e35ba22e  10dc218c0a7b0f        0       0
# 24      098a313165cf1f  08c483c5a4892f  d3fbbd5cb133ab        1       0
# 28      6804a61e2bc741  5e7b470bc618e9  c72337523af115        1       3
# 30      fc21e8a7b41b99  32d10c4f87a8e1  700b82ea04a64a        0       1
# 35      c9292dc183c209  8d4352dda80cea  8d0cc89664fbad        0       0
# 47      239a4a28e3c9e4  f1e98a532b8b84  197ec054322d8e        1       1
# 54      d2190a1303cf04  778dfc9093ce12  12c0804cbbfc5a        0       0
# 60      5cce20dd79d38a  494fe28700a94b  ce1e7d11e50353        0       0
# 67      7c1a2dd2e68850  8af1dd4cddc464  b1066632439eb0        0       0
# 80      ae8f5aac0b4d29  da174d1521aa9b  3ed18341d9a3dd        0       1
# 9805         1534.00                7       1500        0.1429
# 11781        2454.00                7          0        0.6538
# 12156          81.00                2          0        0.0345
# 12775         121.20               21          0        0.1250
# 14714        4371.00                7          0        0.5909
# 18716         936.20                5          0        0.8889
# 21607         687.90                5       1500        0.8605
# 23427          35.24                2          0        0.0000
# 25072         884.20                2          0        0.4524
# 27827         506.80                5          0        0.3077
# 31620         963.60               10          0        0.4783
# 36638         559.80                1          0        0.2500
# 46025           0.00               13          0        0.2500
# 47912        1513.00                9          0        0.3929
# 67598         932.60               22          0        0.8333
# 73327         150.50               25       1500        0.5000
# 98481          94.83               20          0        0.7500
# 108308        516.20                3       1500        0.0000
#
# [80 rows x 29 columns]

# %%
df['Id'].is_unique
# Each id value is unique
# Out:
# True

# %%
target = 'winPlacePerc'

# %%
train , test = train_test_split(df, test_size = 0.2)

# %%
x_train = train.drop(target, axis=1)
y_train = train[target]

# x_test = test.drop(target, axis = 1)
# y_test = test[target]

# %%
x_train.isnull().values.any()
# Out:
# False

# %%
groupId = x_train['groupId']
matchId = x_train['matchId']

# %%
#creating and entity set 'es'
es = ft.EntitySet(id = 'Game_Id')

# adding a dataframe 
es.entity_from_dataframe(entity_id = 'id', dataframe = x_train, index = 'index')
# Out:
# 2019-06-28 02:51:54,329 featuretools.entityset - WARNING    index index not found in dataframe, creating new integer column
# Entityset: Game_Id
#   Entities:
#     id [Rows: 200000, Columns: 29]
#   Relationships:
#     No relationships

# %%
es.normalize_entity(base_entity_id='id', new_entity_id='player', index = 'index', 
additional_variables = [
'assists', 
'damageDealt', 
'headshotKills', 
'killPlace', 
'killPoints',
'killStreaks', 
'kills', 
'longestKill', 
'roadKills', 
'vehicleDestroys', 
'DBNOs'
])
# Out:
# Entityset: Game_Id
#   Entities:
#     id [Rows: 200000, Columns: 18]
#     player [Rows: 200000, Columns: 12]
#   Relationships:
#     id.index -> player.index

# %%
es.normalize_entity(base_entity_id='id', new_entity_id='teamCoop', index = 'groupId', 
additional_variables = [
'revives',
'teamKills'
])
# Out:
# Entityset: Game_Id
#   Entities:
#     id [Rows: 200000, Columns: 16]
#     player [Rows: 200000, Columns: 12]
#     teamCoop [Rows: 190553, Columns: 3]
#   Relationships:
#     id.index -> player.index
#     id.groupId -> teamCoop.groupId

# %%
es.normalize_entity(base_entity_id='id', new_entity_id='Movement', index = 'index', 
additional_variables = [

'rideDistance', 
'swimDistance', 
'walkDistance',
'weaponsAcquired',
'boosts',
'heals'
])
# Out:
# Entityset: Game_Id
#   Entities:
#     id [Rows: 200000, Columns: 10]
#     player [Rows: 200000, Columns: 12]
#     teamCoop [Rows: 190553, Columns: 3]
#     Movement [Rows: 200000, Columns: 7]
#   Relationships:
#     id.index -> player.index
#     id.groupId -> teamCoop.groupId
#     id.index -> Movement.index

# %%
feature_matrix, feature_names = ft.dfs(entityset=es, 
target_entity = 'id', 
max_depth = 2, 
verbose = 1, 
n_jobs = -1)
# Out:
# Built 142 features
# distributed.utils - ERROR -
# Traceback (most recent call last):
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 713, in log_errors
#     yield
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1246, in _close
#     quiet_exceptions=(CancelledError,),
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 965, in with_timeout
#     chain_future(future, result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 611, in chain_future
#     future_add_done_callback(a, copy)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 658, in future_add_done_callback
#     callback(future)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 606, in copy
#     elif a.exception() is not None:
# concurrent.futures._base.CancelledError
# Exception ignored in: <bound method Client.__del__ of <Client: not connected>>
# Traceback (most recent call last):
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1097, in __del__
#     self.close()
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1322, in close
#     sync(self.loop, self._close, fast=True)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 331, in sync
#     six.reraise(*error[0])
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\six.py", line 693, in reraise
#     raise value
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 316, in f
#     result[0] = yield future
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 1133, in run
#     value = future.result()
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1246, in _close
#     quiet_exceptions=(CancelledError,),
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 965, in with_timeout
#     chain_future(future, result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 611, in chain_future
#     future_add_done_callback(a, copy)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 658, in future_add_done_callback
#     callback(future)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 606, in copy
#     elif a.exception() is not None:
# concurrent.futures._base.CancelledError:
# distributed.utils - ERROR -
# Traceback (most recent call last):
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 713, in log_errors
#     yield
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1246, in _close
#     quiet_exceptions=(CancelledError,),
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 965, in with_timeout
#     chain_future(future, result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 611, in chain_future
#     future_add_done_callback(a, copy)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 658, in future_add_done_callback
#     callback(future)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 606, in copy
#     elif a.exception() is not None:
# concurrent.futures._base.CancelledError
# Exception ignored in: <bound method Client.__del__ of <Client: not connected>>
# Traceback (most recent call last):
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1097, in __del__
#     self.close()
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1322, in close
#     sync(self.loop, self._close, fast=True)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 331, in sync
#     six.reraise(*error[0])
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\six.py", line 693, in reraise
#     raise value
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 316, in f
#     result[0] = yield future
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 1133, in run
#     value = future.result()
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1246, in _close
#     quiet_exceptions=(CancelledError,),
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 965, in with_timeout
#     chain_future(future, result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 611, in chain_future
#     future_add_done_callback(a, copy)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 658, in future_add_done_callback
#     callback(future)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 606, in copy
#     elif a.exception() is not None:
# concurrent.futures._base.CancelledError:
# EntitySet scattered to 10 workers in 43 seconds
# Elapsed: 03:45 | Remaining: 00:00 | Progress: 100%|██████████████████████████████████████████| Calculated: 10/10 chunks

# %%
feature_matrix.shape
# Out:
# (200000, 142)
# distributed.client - ERROR - Failed to reconnect to scheduler after 10.00 seconds, closing client
# distributed.utils - ERROR -
# Traceback (most recent call last):
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 713, in log_errors
#     yield
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1246, in _close
#     quiet_exceptions=(CancelledError,),
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 965, in with_timeout
#     chain_future(future, result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 611, in chain_future
#     future_add_done_callback(a, copy)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 658, in future_add_done_callback
#     callback(future)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 606, in copy
#     elif a.exception() is not None:
# concurrent.futures._base.CancelledError
# distributed.utils - ERROR -
# Traceback (most recent call last):
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 713, in log_errors
#     yield
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1003, in _reconnect
#     yield self._close()
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 1133, in run
#     value = future.result()
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1246, in _close
#     quiet_exceptions=(CancelledError,),
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 965, in with_timeout
#     chain_future(future, result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 611, in chain_future
#     future_add_done_callback(a, copy)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 658, in future_add_done_callback
#     callback(future)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 606, in copy
#     elif a.exception() is not None:
# concurrent.futures._base.CancelledError

# %%
y_train.shape
# Out:
# (200000,)

# %%
x_train = feature_matrix

# %%
from sklearn.model_selection import train_test_split

# splitting train data into training and validation set
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.25, random_state=11)

# %%
x_train.head()
# Out:
#                     Id         groupId         matchId  matchDuration  \
# index
# 138412  f508a48c9e9d9f  9b99b301ee3527  661f2d1d5b5075           1916
# 105651  6f685e818a797f  606a50ee1221b5  11d577d478f3d5           1343
# 175345  d5bc93fadad3fa  c65b437f5283fe  b7f7692812bfc0           1874
# 107238  5fbeaffa2d4c05  290b21c35f7e0f  a8488071e08d9d           1422
# 61210   7963e84df155cf  5b8b05e0d0fda7  4d126c113bfb79           1228
#
#         matchType  maxPlace  numGroups  rankPoints  winPoints  player.assists  \
# index
# 138412    duo-fpp        49         47        1535          0               1
# 105651  squad-fpp        28         28          -1       1489               0
# 175345    duo-fpp        48         46        1517          0               0
# 107238       solo        98         96          -1       1571               0
# 61210     duo-fpp        46         45        1730          0               0
#
#         ...  Movement.MEAN(id.rankPoints)  Movement.MEAN(id.winPoints)  \
# index   ...
# 138412  ...                          1535                            0
# 105651  ...                            -1                         1489
# 175345  ...                          1517                            0
# 107238  ...                            -1                         1571
# 61210   ...                          1730                            0
#
#         Movement.NUM_UNIQUE(id.Id)  Movement.NUM_UNIQUE(id.groupId)  \
# index
# 138412                           1                                1
# 105651                           1                                1
# 175345                           1                                1
# 107238                           1                                1
# 61210                            1                                1
#
#         Movement.NUM_UNIQUE(id.matchId)  Movement.NUM_UNIQUE(id.matchType)  \
# index
# 138412                                1                                  1
# 105651                                1                                  1
# 175345                                1                                  1
# 107238                                1                                  1
# 61210                                 1                                  1
#
#         Movement.MODE(id.Id)  Movement.MODE(id.groupId)  \
# index
# 138412        f508a48c9e9d9f             9b99b301ee3527
# 105651        6f685e818a797f             606a50ee1221b5
# 175345        d5bc93fadad3fa             c65b437f5283fe
# 107238        5fbeaffa2d4c05             290b21c35f7e0f
# 61210         7963e84df155cf             5b8b05e0d0fda7
#
#         Movement.MODE(id.matchId)  Movement.MODE(id.matchType)
# index
# 138412             661f2d1d5b5075                      duo-fpp
# 105651             11d577d478f3d5                    squad-fpp
# 175345             b7f7692812bfc0                      duo-fpp
# 107238             a8488071e08d9d                         solo
# 61210              4d126c113bfb79                      duo-fpp
#
# [5 rows x 142 columns]

# %%
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,scale
from sklearn import neighbors
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from math import sqrt
import matplotlib.pyplot as plt
import numpy as np

# %%
x_train = x_train.select_dtypes(exclude=['object'])

# %%
x_train.dtypes
# Out:
# matchDuration                          int64
# maxPlace                               int64
# numGroups                              int64
# rankPoints                             int64
# winPoints                              int64
# player.assists                         int64
# player.damageDealt                   float64
# player.headshotKills                   int64
# player.killPlace                       int64
# player.killPoints                      int64
# player.killStreaks                     int64
# player.kills                           int64
# player.longestKill                   float64
# player.roadKills                       int64
# player.vehicleDestroys                 int64
# player.DBNOs                           int64
# teamCoop.revives                       int64
# teamCoop.teamKills                     int64
# Movement.rideDistance                float64
# Movement.swimDistance                float64
# Movement.walkDistance                float64
# Movement.weaponsAcquired               int64
# Movement.boosts                        int64
# Movement.heals                         int64
# player.SUM(id.matchDuration)           int64
# player.SUM(id.maxPlace)                int64
# player.SUM(id.numGroups)               int64
# player.SUM(id.rankPoints)              int64
# player.SUM(id.winPoints)               int64
# player.STD(id.matchDuration)         float64
#                                       ...
# Movement.SUM(id.winPoints)             int64
# Movement.STD(id.matchDuration)       float64
# Movement.STD(id.maxPlace)            float64
# Movement.STD(id.numGroups)           float64
# Movement.STD(id.rankPoints)          float64
# Movement.STD(id.winPoints)           float64
# Movement.MAX(id.matchDuration)         int64
# Movement.MAX(id.maxPlace)              int64
# Movement.MAX(id.numGroups)             int64
# Movement.MAX(id.rankPoints)            int64
# Movement.MAX(id.winPoints)             int64
# Movement.SKEW(id.matchDuration)      float64
# Movement.SKEW(id.maxPlace)           float64
# Movement.SKEW(id.numGroups)          float64
# Movement.SKEW(id.rankPoints)         float64
# Movement.SKEW(id.winPoints)          float64
# Movement.MIN(id.matchDuration)         int64
# Movement.MIN(id.maxPlace)              int64
# Movement.MIN(id.numGroups)             int64
# Movement.MIN(id.rankPoints)            int64
# Movement.MIN(id.winPoints)             int64
# Movement.MEAN(id.matchDuration)        int64
# Movement.MEAN(id.maxPlace)             int64
# Movement.MEAN(id.numGroups)            int64
# Movement.MEAN(id.rankPoints)           int64
# Movement.MEAN(id.winPoints)            int64
# Movement.NUM_UNIQUE(id.Id)             int64
# Movement.NUM_UNIQUE(id.groupId)        int64
# Movement.NUM_UNIQUE(id.matchId)        int64
# Movement.NUM_UNIQUE(id.matchType)      int64
# Length: 127, dtype: object

# %%
x_train.shape
# Out:
# (150000, 127)

# %%
x_train.isnull().values.any()
# Out:
# True

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
x_train.isnull().sum()
# Out:
# matchDuration                             0
# maxPlace                                  0
# numGroups                                 0
# rankPoints                                0
# winPoints                                 0
# player.assists                            0
# player.damageDealt                        0
# player.headshotKills                      0
# player.killPlace                          0
# player.killPoints                         0
# player.killStreaks                        0
# player.kills                              0
# player.longestKill                        0
# player.roadKills                          0
# player.vehicleDestroys                    0
# player.DBNOs                              0
# teamCoop.revives                          0
# teamCoop.teamKills                        0
# Movement.rideDistance                     0
# Movement.swimDistance                     0
# Movement.walkDistance                     0
# Movement.weaponsAcquired                  0
# Movement.boosts                           0
# Movement.heals                            0
# player.SUM(id.matchDuration)              0
# player.SUM(id.maxPlace)                   0
# player.SUM(id.numGroups)                  0
# player.SUM(id.rankPoints)                 0
# player.SUM(id.winPoints)                  0
# player.STD(id.matchDuration)         150000
# player.STD(id.maxPlace)              150000
# player.STD(id.numGroups)             150000
# player.STD(id.rankPoints)            150000
# player.STD(id.winPoints)             150000
# player.MAX(id.matchDuration)              0
# player.MAX(id.maxPlace)                   0
# player.MAX(id.numGroups)                  0
# player.MAX(id.rankPoints)                 0
# player.MAX(id.winPoints)                  0
# player.SKEW(id.matchDuration)        150000
# player.SKEW(id.maxPlace)             150000
# player.SKEW(id.numGroups)            150000
# player.SKEW(id.rankPoints)           150000
# player.SKEW(id.winPoints)            150000
# player.MIN(id.matchDuration)              0
# player.MIN(id.maxPlace)                   0
# player.MIN(id.numGroups)                  0
# player.MIN(id.rankPoints)                 0
# player.MIN(id.winPoints)                  0
# player.MEAN(id.matchDuration)             0
# player.MEAN(id.maxPlace)                  0
# player.MEAN(id.numGroups)                 0
# player.MEAN(id.rankPoints)                0
# player.MEAN(id.winPoints)                 0
# player.NUM_UNIQUE(id.Id)                  0
# player.NUM_UNIQUE(id.groupId)             0
# player.NUM_UNIQUE(id.matchId)             0
# player.NUM_UNIQUE(id.matchType)           0
# teamCoop.SUM(id.matchDuration)            0
# teamCoop.SUM(id.maxPlace)                 0
# teamCoop.SUM(id.numGroups)                0
# teamCoop.SUM(id.rankPoints)               0
# teamCoop.SUM(id.winPoints)                0
# teamCoop.STD(id.matchDuration)       136080
# teamCoop.STD(id.maxPlace)            136080
# teamCoop.STD(id.numGroups)           136080
# teamCoop.STD(id.rankPoints)          136080
# teamCoop.STD(id.winPoints)           136080
# teamCoop.MAX(id.matchDuration)            0
# teamCoop.MAX(id.maxPlace)                 0
# teamCoop.MAX(id.numGroups)                0
# teamCoop.MAX(id.rankPoints)               0
# teamCoop.MAX(id.winPoints)                0
# teamCoop.SKEW(id.matchDuration)      149061
# teamCoop.SKEW(id.maxPlace)           149061
# teamCoop.SKEW(id.numGroups)          149061
# teamCoop.SKEW(id.rankPoints)         149061
# teamCoop.SKEW(id.winPoints)          149061
# teamCoop.MIN(id.matchDuration)            0
# teamCoop.MIN(id.maxPlace)                 0
# teamCoop.MIN(id.numGroups)                0
# teamCoop.MIN(id.rankPoints)               0
# teamCoop.MIN(id.winPoints)                0
# teamCoop.MEAN(id.matchDuration)           0
# teamCoop.MEAN(id.maxPlace)                0
# teamCoop.MEAN(id.numGroups)               0
# teamCoop.MEAN(id.rankPoints)              0
# teamCoop.MEAN(id.winPoints)               0
# teamCoop.NUM_UNIQUE(id.index)             0
# teamCoop.NUM_UNIQUE(id.Id)                0
# teamCoop.NUM_UNIQUE(id.matchId)           0
# teamCoop.NUM_UNIQUE(id.matchType)         0
# teamCoop.MODE(id.index)                   0
# Movement.SUM(id.matchDuration)            0
# Movement.SUM(id.maxPlace)                 0
# Movement.SUM(id.numGroups)                0
# Movement.SUM(id.rankPoints)               0
# Movement.SUM(id.winPoints)                0
# Movement.STD(id.matchDuration)       150000
# Movement.STD(id.maxPlace)            150000
# Movement.STD(id.numGroups)           150000
# Movement.STD(id.rankPoints)          150000
# Movement.STD(id.winPoints)           150000
# Movement.MAX(id.matchDuration)            0
# Movement.MAX(id.maxPlace)                 0
# Movement.MAX(id.numGroups)                0
# Movement.MAX(id.rankPoints)               0
# Movement.MAX(id.winPoints)                0
# Movement.SKEW(id.matchDuration)      150000
# Movement.SKEW(id.maxPlace)           150000
# Movement.SKEW(id.numGroups)          150000
# Movement.SKEW(id.rankPoints)         150000
# Movement.SKEW(id.winPoints)          150000
# Movement.MIN(id.matchDuration)            0
# Movement.MIN(id.maxPlace)                 0
# Movement.MIN(id.numGroups)                0
# Movement.MIN(id.rankPoints)               0
# Movement.MIN(id.winPoints)                0
# Movement.MEAN(id.matchDuration)           0
# Movement.MEAN(id.maxPlace)                0
# Movement.MEAN(id.numGroups)               0
# Movement.MEAN(id.rankPoints)              0
# Movement.MEAN(id.winPoints)               0
# Movement.NUM_UNIQUE(id.Id)                0
# Movement.NUM_UNIQUE(id.groupId)           0
# Movement.NUM_UNIQUE(id.matchId)           0
# Movement.NUM_UNIQUE(id.matchType)         0
# dtype: int64

# %%
x_train = x_train.dropna(axis='columns')

# %%
x_train.isnull().sum()
# Out:
# matchDuration                        0
# maxPlace                             0
# numGroups                            0
# rankPoints                           0
# winPoints                            0
# player.assists                       0
# player.damageDealt                   0
# player.headshotKills                 0
# player.killPlace                     0
# player.killPoints                    0
# player.killStreaks                   0
# player.kills                         0
# player.longestKill                   0
# player.roadKills                     0
# player.vehicleDestroys               0
# player.DBNOs                         0
# teamCoop.revives                     0
# teamCoop.teamKills                   0
# Movement.rideDistance                0
# Movement.swimDistance                0
# Movement.walkDistance                0
# Movement.weaponsAcquired             0
# Movement.boosts                      0
# Movement.heals                       0
# player.SUM(id.matchDuration)         0
# player.SUM(id.maxPlace)              0
# player.SUM(id.numGroups)             0
# player.SUM(id.rankPoints)            0
# player.SUM(id.winPoints)             0
# player.MAX(id.matchDuration)         0
# player.MAX(id.maxPlace)              0
# player.MAX(id.numGroups)             0
# player.MAX(id.rankPoints)            0
# player.MAX(id.winPoints)             0
# player.MIN(id.matchDuration)         0
# player.MIN(id.maxPlace)              0
# player.MIN(id.numGroups)             0
# player.MIN(id.rankPoints)            0
# player.MIN(id.winPoints)             0
# player.MEAN(id.matchDuration)        0
# player.MEAN(id.maxPlace)             0
# player.MEAN(id.numGroups)            0
# player.MEAN(id.rankPoints)           0
# player.MEAN(id.winPoints)            0
# player.NUM_UNIQUE(id.Id)             0
# player.NUM_UNIQUE(id.groupId)        0
# player.NUM_UNIQUE(id.matchId)        0
# player.NUM_UNIQUE(id.matchType)      0
# teamCoop.SUM(id.matchDuration)       0
# teamCoop.SUM(id.maxPlace)            0
# teamCoop.SUM(id.numGroups)           0
# teamCoop.SUM(id.rankPoints)          0
# teamCoop.SUM(id.winPoints)           0
# teamCoop.MAX(id.matchDuration)       0
# teamCoop.MAX(id.maxPlace)            0
# teamCoop.MAX(id.numGroups)           0
# teamCoop.MAX(id.rankPoints)          0
# teamCoop.MAX(id.winPoints)           0
# teamCoop.MIN(id.matchDuration)       0
# teamCoop.MIN(id.maxPlace)            0
# teamCoop.MIN(id.numGroups)           0
# teamCoop.MIN(id.rankPoints)          0
# teamCoop.MIN(id.winPoints)           0
# teamCoop.MEAN(id.matchDuration)      0
# teamCoop.MEAN(id.maxPlace)           0
# teamCoop.MEAN(id.numGroups)          0
# teamCoop.MEAN(id.rankPoints)         0
# teamCoop.MEAN(id.winPoints)          0
# teamCoop.NUM_UNIQUE(id.index)        0
# teamCoop.NUM_UNIQUE(id.Id)           0
# teamCoop.NUM_UNIQUE(id.matchId)      0
# teamCoop.NUM_UNIQUE(id.matchType)    0
# teamCoop.MODE(id.index)              0
# Movement.SUM(id.matchDuration)       0
# Movement.SUM(id.maxPlace)            0
# Movement.SUM(id.numGroups)           0
# Movement.SUM(id.rankPoints)          0
# Movement.SUM(id.winPoints)           0
# Movement.MAX(id.matchDuration)       0
# Movement.MAX(id.maxPlace)            0
# Movement.MAX(id.numGroups)           0
# Movement.MAX(id.rankPoints)          0
# Movement.MAX(id.winPoints)           0
# Movement.MIN(id.matchDuration)       0
# Movement.MIN(id.maxPlace)            0
# Movement.MIN(id.numGroups)           0
# Movement.MIN(id.rankPoints)          0
# Movement.MIN(id.winPoints)           0
# Movement.MEAN(id.matchDuration)      0
# Movement.MEAN(id.maxPlace)           0
# Movement.MEAN(id.numGroups)          0
# Movement.MEAN(id.rankPoints)         0
# Movement.MEAN(id.winPoints)          0
# Movement.NUM_UNIQUE(id.Id)           0
# Movement.NUM_UNIQUE(id.groupId)      0
# Movement.NUM_UNIQUE(id.matchId)      0
# Movement.NUM_UNIQUE(id.matchType)    0
# dtype: int64

# %%
x_train.shape
# Out:
# (150000, 97)

# %%
clf = GradientBoostingRegressor(n_estimators=200,min_samples_leaf=2,max_depth=3)
clf.fit(x_train, y_train)
# Out:
# distributed.utils - ERROR -
# Traceback (most recent call last):
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 713, in log_errors
#     yield
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1246, in _close
#     quiet_exceptions=(CancelledError,),
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 965, in with_timeout
#     chain_future(future, result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 611, in chain_future
#     future_add_done_callback(a, copy)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 658, in future_add_done_callback
#     callback(future)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 606, in copy
#     elif a.exception() is not None:
# concurrent.futures._base.CancelledError
# Exception ignored in: <bound method Client.__del__ of <Client: not connected>>
# Traceback (most recent call last):
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1097, in __del__
#     self.close()
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1322, in close
#     sync(self.loop, self._close, fast=True)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 331, in sync
#     six.reraise(*error[0])
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\six.py", line 693, in reraise
#     raise value
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\utils.py", line 316, in f
#     result[0] = yield future
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 1133, in run
#     value = future.result()
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py", line 1246, in _close
#     quiet_exceptions=(CancelledError,),
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 965, in with_timeout
#     chain_future(future, result)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 611, in chain_future
#     future_add_done_callback(a, copy)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 658, in future_add_done_callback
#     callback(future)
#   File "c:\users\sebastian\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 606, in copy
#     elif a.exception() is not None:
# concurrent.futures._base.CancelledError:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=2, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=200,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
x_valid = x_valid.select_dtypes(exclude=['object'])
x_valid = x_valid.dropna(axis='columns')

# %%
y_pred = clf.predict(x_valid)

# %%
error = mean_absolute_error(y_valid,y_pred) #calculate err
print('MAE value  is:', error)
# Out:
# MAE value  is: 0.06557679805250811

# %%
error_RMSE = math.sqrt(mean_squared_error(y_test,y_pred)) #calculate err
print('RMSE value  is:', error_RMSE)
r2 = r2_score(y_test, y_pred)
print('R2: ', r2)
